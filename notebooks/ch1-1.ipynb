# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
url = "http://www.ipss.go.jp/p-toukei/JMD/00/STATS/Births.txt"

df_birth = pd.read_csv(url, skiprows=1, delim_whitespace=True)
df_birth
# Out:
#     Year   Female     Male    Total
# 0   1947  1301806  1376986  2678792
# 1   1948  1303060  1378564  2681624
# 2   1949  1316630  1380008  2696638
# 3   1950  1134396  1203111  2337507
# 4   1951  1043048  1094641  2137689
# ..   ...      ...      ...      ...
# 66  2013   502159   527657  1029816
# 67  2014   488006   515533  1003539
# 68  2015   490225   515452  1005677
# 69  2016   475098   501880   976978
# 70  2017   461616   484449   946065
#
# [71 rows x 4 columns]

# %%
df_birth_F = df_birth[["Year", "Female"]].copy()
df_birth_F.columns = ["year", "l"]
df_birth_F["sex"] = "F"

df_birth_M = df_birth[["Year", "Male"]].copy()
df_birth_M.columns = ["year", "l"]
df_birth_M["sex"] = "M"

df_birth = pd.concat([df_birth_F, df_birth_M], axis=0, ignore_index=True)
df_birth
# Out:
#      year        l sex
# 0    1947  1301806   F
# 1    1948  1303060   F
# 2    1949  1316630   F
# 3    1950  1134396   F
# 4    1951  1043048   F
# ..    ...      ...  ..
# 137  2013   527657   M
# 138  2014   515533   M
# 139  2015   515452   M
# 140  2016   501880   M
# 141  2017   484449   M
#
# [142 rows x 3 columns]

# %%
df_birth["ratio"] = df_birth["l"] / df_birth["l"].sum()
df_birth["cum_ratio"] = df_birth["ratio"].cumsum()
del df_birth["l"]

df_birth
# Out:
#      year sex     ratio  cum_ratio
# 0    1947   F  0.012044   0.012044
# 1    1948   F  0.012055   0.024099
# 2    1949   F  0.012181   0.036279
# 3    1950   F  0.010495   0.046774
# 4    1951   F  0.009650   0.056424
# ..    ...  ..       ...        ...
# 137  2013   M  0.004882   0.981337
# 138  2014   M  0.004769   0.986106
# 139  2015   M  0.004769   0.990875
# 140  2016   M  0.004643   0.995518
# 141  2017   M  0.004482   1.000000
#
# [142 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

x = df_birth.index
y = df_birth["cum_ratio"]
plt.plot(x, y);

# %%
url = ""
